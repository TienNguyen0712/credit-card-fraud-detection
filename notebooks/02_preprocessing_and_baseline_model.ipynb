# %% [markdown]
# <a href="https://colab.research.google.com/github/TienNguyen0712/credit-card-fraud-detection/blob/main/notebooks/02_preprocessing_and_baseline_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🧪 **Preprocessing And Baseline Model (Tiền xử lý dữ liệu và Mô hình cốt lõi)**
#
# > Mục tiêu: Lựa chọn các đặc trưng, thực hiện xử lý mất cân bằng dữ liệu, huấn luyện mô hình cơ sở

# %% [markdown]
# ## ⚙️ **Preprocessing Data (Chuẩn bị dữ liệu)**
#
# Việc xử lý dữ liệu mất cân bằng sẽ ngăn chặn việc mô hình sẽ học "lười" làm giảm độ chính xác của mô hình
#
# ### **Undersampling**
#
# Cắt giảm số lượng mẫu của nhóm đa số để bằng với số lượng mẫu của nhóm
#
# Xóa ngẫu nhiên các nhóm đa số cho đến khi tỷ lệ giữa hai nhóm là 50/50 hoặc một phần tỉ lệ mong muốn
#
# ### **Oversampling**
#
# Làm tăng số lượng mẫu của nhóm thiểu số lên
# - Random: Sao chép y hệt các mẫu cần tăng
# - SMOTE: Tạo ra các điểm dữ liệu giả, nhưng trông giống thật bằng cách nối các điểm dữ liệu gian lận gân nhau và lấy một điểm nằm trên đoạn thằng đó
#
# ### **Class weight**
#
# Gán cho các mẫu thiểu số một "hình phạt" nặng hơn khi mô hình đoán sai

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import RobustScaler
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
import xgboost as xgb
from sklearn.metrics import classification_report, precision_recall_curve, average_precision_score
from sklearn.model_selection import StratifiedKFold, cross_val_score, learning_curve
from sklearn.pipeline import Pipeline
from imblearn.over_sampling import SMOTE
from collections import Counter

# %%
# !pip install xgboost
# Out:
# Requirement already satisfied: xgboost in /usr/local/lib/python3.12/dist-packages (3.2.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from xgboost) (2.0.2)
# Requirement already satisfied: nvidia-nccl-cu12 in /usr/local/lib/python3.12/dist-packages (from xgboost) (2.29.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from xgboost) (1.16.3)

# %%
df = pd.read_csv("df_cleaned.csv")
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V23       V24       V25       V26       V27  \
# 0  0.098698  0.363787  ... -0.110474  0.066928  0.128539 -0.189115  0.133558
# 1  0.085102 -0.255425  ...  0.101288 -0.339846  0.167170  0.125895 -0.008983
# 2  0.247676 -1.514654  ...  0.909412 -0.689281 -0.327642 -0.139097 -0.055353
# 3  0.377436 -1.387024  ... -0.190321 -1.175575  0.647376 -0.221929  0.062723
# 4 -0.270533  0.817739  ... -0.137458  0.141267 -0.206010  0.502292  0.219422
#
#         V28  Amount  Class  Hour  Amount_log
# 0 -0.021053  149.62      0   0.0    5.014760
# 1  0.014724    2.69      0   0.0    1.305626
# 2 -0.059752  378.66      0   0.0    5.939276
# 3  0.061458  123.50      0   0.0    4.824306
# 4  0.215153   69.99      0   0.0    4.262539
#
# [5 rows x 33 columns]

# %% [markdown]
# ## 🛃 **Split Data And Train (Chia dữ liệu và thực hiện xử lý mất cân bằng)**

# %% [markdown]
# ### **Phương pháp đánh giá**
#
# - **Precision - Recall** Curve:
# Chỉ số Precsion và Recall đều tập chung vào các giao dịch gian lận được bắt chúng. Phản ánh trực tiếp khả năng tìm thấy só lượng nhỏ mà không bị rò ri thông tin
# - **Confusion-Maxtrix:** Nhằm đánh giá trên tập dữ liệu có bao nhiêu giao dịch là đoán đúng là gian lận
#
# ### **Phương pháp chuẩn hóa**
#
# - **RobustScaler:** Hoạt động dựa trên Trung vị và khoảng biến thiên tứ phân vị. Do dữ liệu có nhiều nhiều và giá trị ngoại lệ cực lớn
#
# **Công thức**
#
# $$x_{scaled} = \frac{x - \text{median}(x)}{Q_3(x) - Q_1(x)}$$

# %%
features = df.drop(columns=["Class", "Time", "Amount"])
target = df["Class"]

# %%
scaler = RobustScaler()
# Chia tập dữ liệu
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2, random_state=42, stratify=target)
X_train['Amount_log'] = scaler.fit_transform(X_train['Amount_log'].values.reshape(-1, 1))
X_test['Amount_log'] = scaler.transform(X_test['Amount_log'].values.reshape(-1, 1))

# %% [markdown]
# ### **Phương pháp 1: Sử dụng SMOTE kết hợp cùng mô hình cơ sở**

# %%
# Chỉ thực hiện SMOTE trên tập TRAIN
sm = SMOTE(random_state=42)
X_train_res, y_train_res = sm.fit_resample(X_train, y_train)

print(f"Tỉ lệ sau SMOTE: {Counter(y_train_res)}")

# Huấn luyện mô hình trên dữ liệu đã cân bằng
model_smote = LogisticRegression(max_iter=1000, random_state=42)
model_smote.fit(X_train_res, y_train_res)

y_pred_smote = model_smote.predict(X_test)
print("--- Kết quả với SMOTE ---")
print(classification_report(y_test, y_pred_smote))
# Out:
# Tỉ lệ sau SMOTE: Counter({0: 174146, 1: 174146})
# --- Kết quả với SMOTE ---
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99     43536
#            1       0.08      0.93      0.14        95
#
#     accuracy                           0.98     43631
#    macro avg       0.54      0.95      0.57     43631
# weighted avg       1.00      0.98      0.99     43631

# %% [markdown]
# **Nhận xét**
# - **Lớp gian lận (1)**
#   - **Recall = 0.93:** Mô hình nhận diện thành công 93% tổng số các vụ gian lận thực tế
#   - **Precision = 0.08:** Trong tất cả các giao dịch mà mô hình gắn thẻ "gian lận" thì có 8% là thực sự gian lận
#     - **Tức là** các phần còn lại là bảo động giả, khách hàng bình thường sẽ bị khóa thẻ nhầm lẫn rất nhiều
#   - **F1-Score = 0.15:** Nất cân bằng giữa việc bắt đúng gian lân và việc không làm phiền khách hàng
# - **Lớp không gian lận (0)**
#   - Mô hình đạt độ chính xác gần như tuyệt đối cho các giao dịch hợp lệ. Tuy nhiên, chỉ số **Recall (0.98)** ở lớp 0 xác nhận lại vấn đề trên: có khoảng 2% giao dịch bình thường đang bị mô hình phân loại nhầm sang gian lận. Với khối lượng giao dịch ngân hàng khổng lồ, 2% này là một con số rất lớn về mặt số lượng tuyệt đối

# %%
def plot_pr_curve(model, X_test, y_test, label):
    y_probs = model.predict_proba(X_test)[:, 1]
    precision, recall, _ = precision_recall_curve(y_test, y_probs)
    plt.plot(recall, precision, label=f'{label} (AP={average_precision_score(y_test, y_probs):.2f})')

plt.figure(figsize=(8, 6))
plot_pr_curve(model_smote, X_test, y_test, "SMOTE")
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('So sánh Precision-Recall Curve')
plt.legend()
plt.show()

# %% [markdown]
# **Nhận xét**
#
# - **Chi số AP = 0.84**: Diện tích dưới đường cong PR, mô hình có khả năng phân loại rất tốt. SMOTE đã giup mô hình học đươc dặc trưng của các giao dịch thay vì dự đoán ngẫu nhiên
#
# - **Dáng đường cong:** Ta có các đánh đổi được rút ra
#   - **Recall từ 0 đến 0.82:** Duy trì mức Precision rất cao. Cho thất có thể bắt được 82% số vụ gian lận mã gần như không bị nhầm lẫn
#   - **Diểm "gãy":** Sau điểm này sụt giảm mạnh
#     - Cố gắng bắt thêm thì Precision sẽ giảm sâu. Hệ quả là khóa nhầm rất nhiều thẻ của khách hàng bình thường
#
# **Đánh giá**
#
# Nếu đưa mô hình này vào thực tế:
#
# - Ngân hàng sẽ ngăn chặn được hầu hết các vụ thất thoát tiền bạc do gian lận
#
# - Tuy nhiên cứ 100 người thì phải gọi để xác nhận có 92 người là trung thực. Rât tốn chi phí vận hành

# %% [markdown]
# ### **Phương pháp 2: Sử dụng Class Weight với mô hình cơ sở**

# %%
model_cw = LogisticRegression(max_iter=1000, class_weight='balanced', random_state=42)
model_cw.fit(X_train, y_train)

y_pred_cw = model_cw.predict(X_test)
print("--- Kết quả với Class Weight ---")
print(classification_report(y_test, y_pred_cw))
# Out:
# --- Kết quả với Class Weight ---
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99     43536
#            1       0.09      0.95      0.16        95
#
#     accuracy                           0.98     43631
#    macro avg       0.54      0.96      0.57     43631
# weighted avg       1.00      0.98      0.99     43631

# %% [markdown]
# **Nhận xét**
# - **Lớp gian lận (1)**
#   - **Recall = 0.95:** Mô hình cũng đã nhận diện thành công 95% tổng số các vụ gian lận thực tế. Biết mặt "kẻ gian" tốt hơn SMOTE
#   - **Presion = 0.09:** Trong số tất cả các giao dịch mà mô hình cho là "gian lận" thì có 9% thực sự là gian lận
#     - Còn lại 91% là các báo động giả. Khách hàng bình thường sẽ bị khóa nhầm rất nhiều
#   - **F1-Score = 0.16:** Mất cân bằng giữa việc bắt đúng gian lận và việc không làm phần khách hàng
# - **Lớp không gian lận (0)**
#   - Đạt độ chính xác gàn như tuyệt đối với giao dịch hợp lệ. Tuy nhiên **Recall = 0.98** cho thấy có khoảng 2% giao dịch bình thường đang bị mô hình phân loại sang gian lận

# %%
def plot_pr_curve(model, X_test, y_test, label):
    y_probs = model.predict_proba(X_test)[:, 1]
    precision, recall, _ = precision_recall_curve(y_test, y_probs)
    plt.plot(recall, precision, label=f'{label} (AP={average_precision_score(y_test, y_probs):.2f})')

plt.figure(figsize=(8, 6))
plot_pr_curve(model_cw, X_test, y_test, "Class weight")
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('So sánh Precision-Recall Curve')
plt.legend()
plt.show()

# %% [markdown]
# **Nhận xét**
#
# - **Chi số AP = 0.88**: Diện tích dưới đường cong PR, mô hình có khả năng phân loại cực kỳ tốt. Class weight đã giup mô hình học đươc dặc trưng của các giao dịch thay vì dự đoán ngẫu nhiên
#
# - **Dáng đường cong:** Ta có các đánh đổi được rút ra
#   - **Recall từ 0 đến 0.82:** Duy trì mức Precision rất cao. Cho thấy có thể bắt được 82% số vụ gian lận mã gần như không bị nhầm lẫn
#   - **Diểm "gãy":** Sau điểm này sụt giảm mạnh
#     - Cố gắng bắt thêm thì Precision sẽ giảm sâu. Hệ quả là khóa nhầm rất nhiều thẻ của khách hàng bình thường

# %% [markdown]
# ## 📈 **Comparison (So sánh)**

# %%
model_xgb = xgb.XGBClassifier(random_state=42)
model_xgb.fit(X_train, y_train)

y_pred_xgb = model_xgb.predict(X_test)
print("--- Kết quả với XGBoost ---")
print(classification_report(y_test, y_pred_xgb))
# Out:
# --- Kết quả với XGBoost ---
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     43536
#            1       0.93      0.84      0.88        95
#
#     accuracy                           1.00     43631
#    macro avg       0.96      0.92      0.94     43631
# weighted avg       1.00      1.00      1.00     43631

# %% [markdown]
# **Nhận xét**
# - **Lớp gian lận (1)**
#   - **Recall = 0.84:** Mô hình đã nhận diện thành công 84% tổng số các vụ gian lận thực tế. Nhận diện được các giao dịch gian lận tốt
#   - **Presicion = 0.93:** Trong số tất cả các giao dịch mà mô hình cho là "gian lận" thì có 93% thực sự là gian lận
#     - Còn lại 7% là các báo động giả. Khách hàng bình thường sẽ bị khóa nhầm
#   - **F1-Score = 0.88:** Cho thấy việc phân loại giữa gian lận và không gian lận là cân bằng
# - **Lớp không gian lận (0)**
#   - Đạt độ chính xác tuyệt đối với giao dịch hợp lệ. Do xuất hiện nhiều lớp giao dịch bình thường nhiều hơn

# %%
def plot_pr_curve(model, X_test, y_test, label):
    y_probs = model.predict_proba(X_test)[:, 1]
    precision, recall, _ = precision_recall_curve(y_test, y_probs)
    plt.plot(recall, precision, label=f'{label} (AP={average_precision_score(y_test, y_probs):.2f})')

plt.figure(figsize=(8, 6))
plot_pr_curve(model_xgb, X_test, y_test, "Class weight")
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('So sánh Precision-Recall Curve')
plt.legend()
plt.show()

# %% [markdown]
# **Nhận xét**
#
# - **Chi số AP = 0.86**: Diện tích dưới đường cong PR, mô hình có khả năng phân loại tốt. XGBoost đã học được dặc trưng của các giao dịch thay vì dự đoán ngẫu nhiên
#
# - **Dáng đường cong:** Ta có các đánh đổi được rút ra
#   - **Recall từ 0 đến 0.84:** Duy trì mức Precision rất cao. Cho thấy có thể bắt được 84% số vụ gian lận mã gần như không bị nhầm lẫn
#   - **Diểm "gãy":** Sau điểm này sụt giảm mạnh
#     - Cố gắng bắt thêm thì Precision sẽ giảm sâu. Hệ quả là khóa nhầm rất nhiều thẻ của khách hàng bình thường

# %%
model_cw_random = RandomForestClassifier(n_estimators=100, class_weight='balanced', n_jobs=-1, random_state=42)
model_cw_random.fit(X_train, y_train)

y_pred_cw_random = model_cw_random.predict(X_test)
print("--- Kết quả với Class Weight ---")
print(classification_report(y_test, y_pred_cw_random))
# Out:
# --- Kết quả với Class Weight ---
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     43536
#            1       0.97      0.81      0.89        95
#
#     accuracy                           1.00     43631
#    macro avg       0.99      0.91      0.94     43631
# weighted avg       1.00      1.00      1.00     43631

# %% [markdown]
# **Nhận xét**
#
# - **Lớp gian lận (1)**
#   - **Recall = 0.81:** Mô hình đã nhận diện thành công 81% tổng số các vụ gian lận thực tế. Nhận diện được các giao dịch gian lận tốt
#   - **Presion = 0.97:** Trong số tất cả các giao dịch mà mô hình cho là "gian lận" thì có 97% thực sự là gian lận
#     - Còn lại 3% là các báo động giả. Khách hàng bình thường sẽ bị khóa nhầm rất nhiều
#   - **F1-Score = 0.89:** Cho thấy việc phân loại giữa gian lận và không gian lận là cân bằng
# - **Lớp không gian lận (0)**
#   - Đạt độ chính xác tuyệt đối với giao dịch hợp lệ. Cho thấy mô hình có khả năng bị overfiting

# %%
def plot_pr_curve(model, X_test, y_test, label):
    y_probs = model.predict_proba(X_test)[:, 1]
    precision, recall, _ = precision_recall_curve(y_test, y_probs)
    plt.plot(recall, precision, label=f'{label} (AP={average_precision_score(y_test, y_probs):.2f})')

plt.figure(figsize=(8, 6))
plot_pr_curve(model_cw_random, X_test, y_test, "Class weight")
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('So sánh Precision-Recall Curve')
plt.legend()
plt.show()

# %% [markdown]
# **Nhận xét**
#
# - **Chi số AP = 0.92**: Diện tích dưới đường cong PR, mô hình có khả năng phân loại cực kỳ tốt. Class weight đã giup mô hình học đươc dặc trưng của các giao dịch thay vì dự đoán ngẫu nhiên
#
# - **Dáng đường cong:** Ta có các đánh đổi được rút ra
#   - **Recall từ 0 đến 0.82:** Duy trì mức Precision rất cao. Cho thấy có thể bắt được 82% số vụ gian lận mã gần như không bị nhầm lẫn
#   - **Diểm "gãy":** Sau điểm này sụt giảm mạnh
#     - Cố gắng bắt thêm thì Precision sẽ giảm sâu. Hệ quả là khóa nhầm rất nhiều thẻ của khách hàng bình thường

# %% [markdown]
# ### **Cross-Validation**
#
# Phương pháp đánh giá hiệu suất mô hình bằng cách chia dữ liệu thành nhiều phần khác nhau. Cho phép mô hình dược huấn luyện và kiểm tra nhiều lần trên các tập con khác nhau của dữ liệu
#
# **Kỹ thuật K-Fold** Chia tập train thành k phần bằng nhau, mô hình sẽ chọn 1 phần làm tập kiểm thử và k-1 phần còn lại để huấn luyện, lặp lại k lần sao cho mỗi phần đều có 1 lần được làm tập kiểm thừ. Tính toán giá trị trung bình cảu các chỉ số đánh giá xem mô hình nào hoạt động ổn định hơn
#
# Trong tập dữ liệu sử dụng **Stratified K-Fold** Do dữ liệu bị mất cân bằng dảm bảo mỗi Fold đều có tỉ lệ dữ liệu tương đương dữ liệu gốc

# %%
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

results = cross_val_score(model_cw, X_train, y_train, cv=skf, scoring='roc_auc')
results_random = cross_val_score(model_cw_random, X_train, y_train, cv=skf, scoring='roc_auc')
results_xgboost = cross_val_score(model_xgb, X_train, y_train, cv=skf, scoring='roc_auc')

print(f"ROC-AUC trung bình (cw): {results.mean():.2f} (+/- {results.std():.2f})")
print(f"ROC-AUC trung bình (random): {results_random.mean():.2f} (+/- {results_random.std():.2f})")
print(f"ROC-AUC trung bình (xgboost): {results_xgboost.mean():.2f} (+/- {results_xgboost.std():.2f})")
# Out:
# ROC-AUC trung bình (cw): 0.99 (+/- 0.01)
# ROC-AUC trung bình (random): 0.96 (+/- 0.02)
# ROC-AUC trung bình (xgboost): 0.69 (+/- 0.22)

# %%
ap_results = cross_val_score(model_cw, X_train, y_train, cv=skf, scoring='average_precision')
ap_results_random = cross_val_score(model_cw_random, X_train, y_train, cv=skf, scoring='average_precision')
ap_results_xgboost = cross_val_score(model_xgb, X_train, y_train, cv=skf, scoring='average_precision')

print(f"AP trung bình (cw): {ap_results.mean():.2f} (+/- {ap_results.std():.2f})")
print(f"AP trung bình (random): {ap_results_random.mean():.2f} (+/- {ap_results_random.std():.2f})")
print(f"AP trung bình (xgboost): {ap_results_xgboost.mean():.2f} (+/- {ap_results_xgboost.std():.2f})")
# Out:
# AP trung bình (cw): 0.89 (+/- 0.03)
# AP trung bình (random): 0.91 (+/- 0.03)
# AP trung bình (xgboost): 0.37 (+/- 0.39)

# %% [markdown]
# **Nhận xét**
#
# Mô hình Logistic cùng với Class Weight đang có khả năng phân loại rất tốt, với độ lệch chuẩn dưới 0.05 ta nhận thấy rằng mô hình ổn định và không phụ thuộc vào việc chia dữ liệu

# %% [markdown]
# ## ✅ **Conclusion (Kết luận)**

# %% [markdown]
# - Các chỉ số nhìn chung mô hình đã nhận diện được đặc điểm của các giao dịch gian lận. Tuy nhiên đa số đều là các báo động giả
# - Không nên sử dụng ngưỡng mặc định. Thử nâng ngưỡng thì có thể kết quả sẽ thay đổi
# - Ưu tiên class-weight: Vì có diện tích dưới đường cong tốt hơn, đồng thời không làm tăng kiến kích thước tập dữ liệu như SMOTE
# - So sánh mô hình ta rút ra kết luận Random Forest cho kết quả tốt hơn với Logistic Regression tuy nhiên về hiệu suất thì kém hơn hoàn toàn. Gỉa sử trong môi trường doanh nghiệp đòi hỏi nhanh và tối thiểu tài nguyên. Việc lựa chọn **Logistic** là hợp lý
